# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import statistics
from scipy import stats
from pandas import DataFrame

from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/WOC 4 (3).0/emnist-letters-train.csv')

# %%
def euclid_distance(x,y):
    return np.sqrt(np.sum(np.square(x-y)))

# %%
X_train=train.drop(["23"],axis=1)
X_train=X_train.to_numpy()

# %%
Y_train = train.iloc[:,0]
Y_train.head()
# Out:
# 0     7
# 1    16
# 2    15
# 3    23
# 4    17
# Name: 23, dtype: int64

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (88799, 784)
# (88799,)

# %%
Y_train=Y_train.to_numpy()

# %%
test = pd.read_csv("/content/drive/MyDrive/WOC 4 (3).0/emnist-letters-test.csv")

# %%
X_test=test.iloc[:,1:785]
X_test.head()
print(X_test.shape)
X_test=X_test.to_numpy()
# Out:
# (14799, 784)

# %%
Y_test=test.iloc[:,0]
Y_test=Y_test.to_numpy()

# %%
def sort_ind_list(list1):
    return sorted(range(len(list1)),key=list1.__getitem__)

# %%
class knn:
    def __init__(self,X_train,Y_train,X_test,k):
        self.X_train=X_train
        self.Y_train=Y_train
        self.X_test=X_test
        self.numrow=len(X_train)
        self.numrow1=len(X_test)
        self.numcol=len(X_train[0])
        self.k=k
    def neighbours(self,X):
        a=np.zeros((self.numrow,1),dtype=int)
        self.X_test=np.tile(X, (self.numrow, 1))
        y= np.square(self.X_test-self.X_train)
        a=np.sqrt(y.sum(axis=1))
        order = np.argsort(a)
        self.Y_train1 = [self.Y_train[i] for i in order]
        return  statistics.mode(self.Y_train1[:self.k])
    def finalout(self):
        Y_answer=np.zeros(self.numrow1,dtype=int)
        for i in range(0,self.numrow1):
            Y_answer[i]=self.neighbours(self.X_test[i]) 
        return Y_answer

# %%
Y_pred=knn(X_train,Y_train,X_test,11).finalout()

# %%
count=0
for i in range(len(Y_test)):
    if Y_test[i]==y_pred[i]:
        count+=1

# %%
accuracy=(count/len(Y_test)*100)
accuracy
